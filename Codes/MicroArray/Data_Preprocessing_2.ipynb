# %%
import pandas as pd

# %%
meta1=pd.read_csv("GSE6791/GSE6791_metadata.csv")

# %%
meta1.head()
# Out:
#   Unnamed: 0 geo_accession age:ch1         Case:ch1 gender:ch1 Tumor Stage:ch1
# 0  GSM155645     GSM155645      35  Cervical cancer     Female              II
# 1  GSM155646     GSM155646      27  Cervical cancer     Female             IB2
# 2  GSM155647     GSM155647      40  Cervical cancer     Female              IB
# 3  GSM155648     GSM155648      42  Cervical cancer     Female              IB
# 4  GSM155649     GSM155649      44  Cervical cancer     Female          II/III

# %%
meta2=pd.read_csv("GSE9750/GSE9750_metadata.csv")
meta2.head()
# Out:
#   Unnamed: 0                             title geo_accession  \
# 0  GSM246087   Cervical cancer cell line, C4-I     GSM246087
# 1  GSM246088  Cervical cancer cell line, CaSki     GSM246088
# 2  GSM246089  Cervical cancer cell line, C-33A     GSM246089
# 3  GSM246090   Cervical cancer cell line, HT-3     GSM246090
# 4  GSM246119   Cervical cancer cell line, SiHa     GSM246119
#
#                     source_name_ch1
# 0   Cervical cancer cell line, C4-I
# 1  Cervical cancer cell line, CaSki
# 2  Cervical cancer cell line, C-33A
# 3   Cervical cancer cell line, HT-3
# 4   Cervical cancer cell line, SiHa

# %%
l1=list(meta1.columns)
l1[0]="ID"
l1[2]="Age"
l1[3]="Cancer"
l1[4]="Gender"
l1[5]="Stage"
l1
# Out:
# ['ID', 'geo_accession', 'Age', 'Cancer', 'Gender', 'Stage']

# %%
meta1.columns=l1

# %%
meta1.drop("geo_accession",axis=1,inplace=True)

# %%
meta1=meta1.set_index("ID")

# %%
df=pd.read_csv("GSE6791/GSE6791_Modified.csv",index_col="GENE SYMBOL")
df.head()

# %%
df.head()
# Out:
#                          ID  GSM155645  GSM155646  GSM155647  GSM155648  \
# GENE SYMBOL
# DDR1 /// MIR4640  1007_s_at  10.926493  11.050830  11.535001  11.780722
# RFC2                1053_at   6.792618   6.309582   6.436999   6.656980
# PAX8                 121_at   9.802401   8.542969   9.361304   9.321631
# MIR5193 /// UBA7    1294_at   8.523952  10.032222   7.389303   8.847466
# THRA                1316_at   6.606872   5.733024   6.119088   5.786545
#
#                   GSM155649  GSM155650  GSM155651  GSM155652  GSM155653  ...  \
# GENE SYMBOL                                                              ...
# DDR1 /// MIR4640  11.731943  11.456500  11.798875  12.072699  11.983531  ...
# RFC2               7.612923   6.767396   6.656845   6.901212   6.697030  ...
# PAX8               8.981502  11.291192   9.225758   9.236232   9.106564  ...
# MIR5193 /// UBA7   9.542878  10.248249   8.292253   8.111228   8.301731  ...
# ...

# %%
df.drop("ID",axis=1,inplace=True)

# %%
df=df.T

# %%
df.to_csv("1.csv")

# %%
meta1
# Out:
#           Age                Cancer  Gender   Stage
# ID
# GSM155645  35       Cervical cancer  Female      II
# GSM155646  27       Cervical cancer  Female     IB2
# GSM155647  40       Cervical cancer  Female      IB
# GSM155648  42       Cervical cancer  Female      IB
# GSM155649  44       Cervical cancer  Female  II/III
# ...        ..                   ...     ...     ...
# GSM155724  63  Head and neck normal  Female     NaN
# GSM155725  88  Head and neck normal  Female     NaN
# GSM155726  54  Head and neck normal  Female     NaN
# GSM155727  84  Head and neck normal    Male     NaN
# GSM155728  81  Head and neck normal  Female     NaN
#
# [84 rows x 4 columns]

# %%
df_joined=pd.merge(df,meta1,left_index=True,right_index=True)

# %%
df_joined.drop("Gender",axis=1,inplace=True)

# %%
df_joined.head()
# Out:
#            DDR1 /// MIR4640      RFC2      PAX8  MIR5193 /// UBA7      THRA  \
# GSM155645         10.926493  6.792618  9.802401          8.523952  6.606872
# GSM155646         11.050830  6.309582  8.542969         10.032222  5.733024
# GSM155647         11.535001  6.436999  9.361304          7.389303  6.119088
# GSM155648         11.780722  6.656980  9.321631          8.847466  5.786545
# GSM155649         11.731943  7.612923  8.981502          9.542878  5.872103
#
#                CCL5     ESRRA    CYP2A6    SCARB1     TTLL12  ...        NaN  \
# GSM155645  5.873463  8.409791  7.884830  7.051175  10.393003  ...  10.723801
# GSM155646  8.044375  7.916889  6.938120  7.959524   9.326298  ...   8.813770
# GSM155647  4.955036  8.197857  7.480601  7.195210  10.087347  ...   7.274024
# GSM155648  6.506034  8.112573  7.369072  7.179351   9.900105  ...   8.147287
# GSM155649  8.522783  8.654920  7.395999  7.202994  10.698199  ...   8.617989
#
# ...

# %%
#1 represents the cancer and 0 represents the normal one
df_joined["Cancer"]=df_joined["Cancer"].map({
    "Cervical cancer":1,
    "Cervical normal":0
})

# %%
df_joined["Cancer"].value_counts()
# Out:
# Cancer
# 1    20
# 0     8
# Name: count, dtype: int64

# %%
df_joined.head()
# Out:
#            DDR1 /// MIR4640      RFC2      PAX8  MIR5193 /// UBA7      THRA  \
# GSM155645         10.926493  6.792618  9.802401          8.523952  6.606872
# GSM155646         11.050830  6.309582  8.542969         10.032222  5.733024
# GSM155647         11.535001  6.436999  9.361304          7.389303  6.119088
# GSM155648         11.780722  6.656980  9.321631          8.847466  5.786545
# GSM155649         11.731943  7.612923  8.981502          9.542878  5.872103
#
#                CCL5     ESRRA    CYP2A6    SCARB1     TTLL12  ...        NaN  \
# GSM155645  5.873463  8.409791  7.884830  7.051175  10.393003  ...  10.723801
# GSM155646  8.044375  7.916889  6.938120  7.959524   9.326298  ...   8.813770
# GSM155647  4.955036  8.197857  7.480601  7.195210  10.087347  ...   7.274024
# GSM155648  6.506034  8.112573  7.369072  7.179351   9.900105  ...   8.147287
# GSM155649  8.522783  8.654920  7.395999  7.202994  10.698199  ...   8.617989
#
# ...

# %%
l2=list(df_joined.columns)

# %%
df_id=pd.read_csv("GSE6791/GSE6791_Modified.csv",index_col="ID")

# %%
df_id.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df_id.drop("GENE SYMBOL",axis=1,inplace=True)

# %%
df_id
# Out:
#                       GSM155645  GSM155646  GSM155647  GSM155648  GSM155649  \
# ID
# 1007_s_at             10.926493  11.050830  11.535001  11.780722  11.731943
# 1053_at                6.792618   6.309582   6.436999   6.656980   7.612923
# 121_at                 9.802401   8.542969   9.361304   9.321631   8.981502
# 1294_at                8.523952  10.032222   7.389303   8.847466   9.542878
# 1316_at                6.606872   5.733024   6.119088   5.786545   5.872103
# ...                         ...        ...        ...        ...        ...
# AFFX-r2-Ec-bioC-5_at  12.006120  10.373284   8.276942   9.841746  10.067670
# AFFX-r2-Ec-bioD-3_at  13.518667  12.146707  11.321140  12.005474  12.149950
# AFFX-r2-Ec-bioD-5_at  13.163059  11.865543  10.881656  11.644203  11.818594
# AFFX-r2-P1-cre-3_at   14.096153  13.679153  12.860447  13.415128  13.550891
# AFFX-r2-P1-cre-5_at   13.994663  13.579994  12.621815  13.249207  13.371064
#
# ...

# %%
df_id=df_id.T

# %%
df_id_joined=pd.merge(df_id,meta1,left_index=True,right_index=True)

# %%
df_id_joined["Cancer"]=df_id_joined["Cancer"].map({
    "Cervical cancer":1,
    "Cervical normal":0
})

# %%
df_id_joined.drop("Gender",axis=1,inplace=True)

# %%
df_id_joined.head()
# Out:
#            1007_s_at   1053_at    121_at    1294_at   1316_at  1405_i_at  \
# GSM155645  10.926493  6.792618  9.802401   8.523952  6.606872   5.873463
# GSM155646  11.050830  6.309582  8.542969  10.032222  5.733024   8.044375
# GSM155647  11.535001  6.436999  9.361304   7.389303  6.119088   4.955036
# GSM155648  11.780722  6.656980  9.321631   8.847466  5.786545   6.506034
# GSM155649  11.731943  7.612923  8.981502   9.542878  5.872103   8.522783
#
#             1487_at  1494_f_at  1552256_a_at  1552257_a_at  ...  \
# GSM155645  8.409791   7.884830      7.051175     10.393003  ...
# GSM155646  7.916889   6.938120      7.959524      9.326298  ...
# GSM155647  8.197857   7.480601      7.195210     10.087347  ...
# GSM155648  8.112573   7.369072      7.179351      9.900105  ...
# GSM155649  8.654920   7.395999      7.202994     10.698199  ...
#
#            AFFX-r2-Ec-bioB-M_at  AFFX-r2-Ec-bioC-3_at  AFFX-r2-Ec-bioC-5_at  \
# ...

# %%
df_id_joined.to_csv("GSE6791_modified_with_metadata.csv")

# %%
meta2.drop("geo_accession",axis=1,inplace=True)

# %%
meta2.columns=["ID","INFO","Cancer"]

# %%
meta2.drop("INFO",axis=1,inplace=True)

# %%
meta2.set_index('ID')
# Out:
#                                      Cancer
# ID
# GSM246087   Cervical cancer cell line, C4-I
# GSM246088  Cervical cancer cell line, CaSki
# GSM246089  Cervical cancer cell line, C-33A
# GSM246090   Cervical cancer cell line, HT-3
# GSM246119   Cervical cancer cell line, SiHa
# ...                                     ...
# GSM247883            Cervical cancer_CaCx54
# GSM247884            Cervical cancer_CaCx60
# GSM247885            Cervical cancer_CaCx70
# GSM247886            Cervical cancer_CaCx81
# GSM247887            Cervical cancer_CaCx83
#
# [66 rows x 1 columns]

# %%
meta2["Cancer"] = meta2["Cancer"].apply(lambda x: 1 if "cancer" in x else 0)

# %%
meta2["Cancer"]
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 61    1
# 62    1
# 63    1
# 64    1
# 65    1
# Name: Cancer, Length: 66, dtype: int64

# %%
meta2=meta2.set_index("ID")

# %%
df_2=pd.read_csv("GSE9750/GSE9750_Modified.csv",index_col="ID")

# %%
df_2.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df_2.drop("GENE SYMBOL",axis=1,inplace=True)

# %%
df_2.head()
# Out:
#            GSM246422  GSM246423  GSM246484  GSM246485  GSM246486  GSM246487  \
# ID
# 1007_s_at   8.881561   9.100208   9.231858  10.848051   9.468050   9.395177
# 1053_at     5.547155   5.642086   5.425129   6.258763   6.074176   6.776772
# 121_at      8.337220   8.363959   8.555399   8.041131   8.394578   8.019541
# 1294_at     7.611945   7.771130   7.700596   8.084805   7.451440   7.582238
# 1316_at     4.968523   5.141198   5.220666   5.285625   5.283509   4.914448
#
#            GSM246488  GSM246489  GSM246490  GSM246491  ...  GSM247877  \
# ID                                                     ...
# 1007_s_at   9.986873   9.935525   9.491053   9.908865  ...   9.116580
# 1053_at     6.156177   6.232879   6.188479   6.277981  ...   5.912201
# 121_at      8.245139   8.339634   8.579346   8.600728  ...   9.164640
# 1294_at     7.459356   7.296470   7.183712   7.575607  ...   7.783962
# 1316_at     5.119933   5.218065   5.530507   5.456108  ...   5.255301
#
# ...

# %%
df_2=df_2.T

# %%
df_2.head()
# Out:
# ID         1007_s_at   1053_at    121_at   1294_at   1316_at  1405_i_at  \
# GSM246422   8.881561  5.547155  8.337220  7.611945  4.968523   5.268977
# GSM246423   9.100208  5.642086  8.363959  7.771130  5.141198   4.956992
# GSM246484   9.231858  5.425129  8.555399  7.700596  5.220666   5.089362
# GSM246485  10.848051  6.258763  8.041131  8.084805  5.285625   5.665267
# GSM246486   9.468050  6.074176  8.394578  7.451440  5.283509   6.172732
#
# ID          1438_at   1487_at  1494_f_at  1598_g_at  ...  \
# GSM246422  7.403100  7.041458   6.246199  11.259800  ...
# GSM246423  7.952545  7.069307   6.127333  10.733498  ...
# GSM246484  7.839180  7.066703   6.452012  10.700817  ...
# GSM246485  7.148712  7.693398   6.415160   9.497024  ...
# GSM246486  7.018930  7.112830   6.608625  10.037073  ...
#
# ID         AFFX-r2-Ec-bioB-3_at  AFFX-r2-Ec-bioB-5_at  AFFX-r2-Ec-bioB-M_at  \
# GSM246422              7.747670              7.461339              8.077131
# ...

# %%
df_id_joined_1=pd.merge(df_2,meta2,left_index=True,right_index=True)

# %%
df_id_joined_1.head()
# Out:
#            1007_s_at   1053_at    121_at   1294_at   1316_at  1405_i_at  \
# GSM246422   8.881561  5.547155  8.337220  7.611945  4.968523   5.268977
# GSM246423   9.100208  5.642086  8.363959  7.771130  5.141198   4.956992
# GSM246484   9.231858  5.425129  8.555399  7.700596  5.220666   5.089362
# GSM246485  10.848051  6.258763  8.041131  8.084805  5.285625   5.665267
# GSM246486   9.468050  6.074176  8.394578  7.451440  5.283509   6.172732
#
#             1438_at   1487_at  1494_f_at  1598_g_at  ...  \
# GSM246422  7.403100  7.041458   6.246199  11.259800  ...
# GSM246423  7.952545  7.069307   6.127333  10.733498  ...
# GSM246484  7.839180  7.066703   6.452012  10.700817  ...
# GSM246485  7.148712  7.693398   6.415160   9.497024  ...
# GSM246486  7.018930  7.112830   6.608625  10.037073  ...
#
#            AFFX-r2-Ec-bioB-5_at  AFFX-r2-Ec-bioB-M_at  AFFX-r2-Ec-bioC-3_at  \
# GSM246422              7.461339              8.077131              9.427703
# ...

# %%
meta2.to_csv("Modified_Metadata_GSE9750.csv")

# %%
meta1.drop("Gender",axis=1,inplace=True)

# %%
meta1_1=pd.read_csv("Metadata_1.csv")

# %%
meta1_1["Cancer"]=meta1_1["Cancer"].apply(lambda x: 1 if "cancer" in x else 0)

# %%
meta1_1.head()
# Out:
#           ID  Age  Cancer   Stage
# 0  GSM155645   35       1      II
# 1  GSM155646   27       1     IB2
# 2  GSM155647   40       1      IB
# 3  GSM155648   42       1      IB
# 4  GSM155649   44       1  II/III

# %%
meta1_1=meta1_1.set_index("ID")

# %%
meta1_1.head()
# Out:
#            Age  Cancer   Stage
# ID
# GSM155645   35       1      II
# GSM155646   27       1     IB2
# GSM155647   40       1      IB
# GSM155648   42       1      IB
# GSM155649   44       1  II/III

# %%
meta1_1.to_csv("Metadata_2.csv",)
